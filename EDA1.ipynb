# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\grzes\downloads\econometrics_projects_codes\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\grzes\downloads\econometrics_projects_codes\.venv\lib\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\grzes\downloads\econometrics_projects_codes\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\grzes\downloads\econometrics_projects_codes\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\grzes\downloads\econometrics_projects_codes\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\grzes\downloads\econometrics_projects_codes\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# ## Let's read Sasha's dataframe with country's macro features

# %%
df = pd.read_csv('filtered&merged.csv')
df.head()
# Out:
#    Unnamed: 0 Country Code  Year Country Name  \
# 0           1          ARG  2015    Argentina
# 1           2          ARG  2016    Argentina
# 2           3          ARG  2017    Argentina
# 3           4          ARG  2018    Argentina
# 4           5          ARG  2019    Argentina
#
#    Researchers in R&D (per million people)  GDP per Capita (USD)  \
# 0                                1231.4866          13679.626498
# 1                                1260.7010          12699.962314
# 2                                1212.4573          14532.500931
# 3                                1227.4042          11752.799892
# 4                                1231.5171           9955.974787
#
#    Research and development expenditure (% of GDP)  \
# 0                                          0.62262
# 1                                          0.55815
# 2                                          0.55631
# 3                                          0.48830
# 4                                          0.47813
#
#    Unemployemnt total (% of total labor force)
# 0                                         7.579
# 1                                         8.085
# 2                                         8.347
# 3                                         9.220
# 4                                         9.843

# %%
print(df['Country Name'].unique())
print(df['Year'].unique())
countries = df['Country Name'].unique()
# Out:
# ['Argentina' 'Austria' 'Belgium' 'Bulgaria' 'Canada' 'China' 'Cyprus'
#  'Czechia' 'Germany' 'Denmark' 'Spain' 'Estonia' 'Finland' 'France'
#  'Georgia' 'Croatia' 'Hungary' 'Ireland' 'Italy' 'Japan' 'Kazakhstan'
#  'Kuwait' 'Lithuania' 'Luxembourg' 'Latvia' 'Mexico' 'North Macedonia'
#  'Netherlands' 'Panama' 'Poland' 'Portugal' 'Romania' 'Russia' 'Singapore'
#  'Serbia' 'Slovakia' 'Slovenia' 'Thailand' 'Turkey' 'Ukraine' 'Uruguay'
#  'United States' 'Uzbekistan']
# [2015 2016 2017 2018 2019 2020]

# %%
len(countries)
# Out:
# 43

# %% [markdown]
# ## Dependent variable - total count of country's residents patent applications

# %%
patents = pd.read_csv('Patents.csv', skiprows=5, index_col = False)
patents.head()
# Out:
#                 Origin Origin (Code) Office   Type   2015   2016   2017  \
# 0              Albania            AL  Total  Total   16.0   36.0   17.0
# 1              Algeria            DZ  Total  Total  106.0  112.0  157.0
# 2              Andorra            AD  Total  Total    NaN   15.0   42.0
# 3               Angola            AO  Total  Total    NaN    NaN    NaN
# 4  Antigua and Barbuda            AG  Total  Total    2.0   84.0   96.0
#
#     2018   2019   2020
# 0   18.0   10.0    NaN
# 1  162.0  119.0  173.0
# 2   14.0   44.0   45.0
# 3   14.0    3.0    NaN
# 4  470.0    NaN  532.0

# %%
# In patents dataframe:
# - Czech Republic needs to be transformed to Czechia
# - Netherlands (Kingdom of the) needs to be transformed to Netherlands
# - Russian Federation needs to be changed to Russia
# - Türkiye must be changed to Turkey
# - United States of America need to be changed to United States
country_rename_map = {
    'Czech Republic': 'Czechia',
    'Netherlands (Kingdom of the)': 'Netherlands',
    'Russian Federation': 'Russia',
    'Türkiye': 'Turkey',
    'United States of America': 'United States'
}
patents['Origin'] = patents['Origin'].replace(country_rename_map)

# %%
patents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Origin         172 non-null    object
#  1   Origin (Code)  171 non-null    object
#  2   Office         172 non-null    object
#  3   Type           172 non-null    object
#  4   2015           142 non-null    float64
#  5   2016           151 non-null    float64
#  6   2017           146 non-null    float64
#  7   2018           148 non-null    float64
#  8   2019           137 non-null    float64
#  9   2020           148 non-null    float64
# dtypes: float64(6), object(4)
# memory usage: 13.6+ KB

# %%
# Let's focus only on the countries from our list
patents_filtered = patents[patents['Origin'].isin(countries)]

# %%
len(patents_filtered['Origin'].unique())
# Out:
# 43

# %%
patents_filtered[patents_filtered.isna().any(axis=1)]
# Out:
#               Origin Origin (Code) Office   Type    2015     2016     2017  \
# 78           Ireland            IE  Total  Total     NaN   4218.0   4234.0
# 80             Italy            IT  Total  Total     NaN  25111.0  25150.0
# 84        Kazakhstan            KZ  Total  Total  1413.0   1100.0   1181.0
# 86            Kuwait            KW  Total  Total     NaN    104.0      NaN
# 115  North Macedonia            MK  Total  Total     NaN      NaN      NaN
# 144         Slovenia            SI  Total  Total     NaN      NaN      NaN
#
#         2018     2019     2020
# 78    5212.0   5286.0   5687.0
# 80   26099.0  25719.0  26168.0
# 84     944.0      NaN    918.0
# 86      90.0      NaN      NaN
# 115      NaN      NaN     90.0
# 144    582.0      NaN    679.0

# %%
# Ireland,Italy and Kazachstan can be filled in with mean value for their rows
# Kuwait, North MAcedonie and Slovenia can be dropped, as they have NaNs for most of the values

# %%
patents_filtered = patents_filtered[~patents_filtered['Origin'].isin(['Kuwait', 'North Macedonia', 'Slovenia'])]

# %%
# List of year columns (to operate only on numeric patent data)
year_cols = ['2015', '2016', '2017', '2018', '2019', '2020']

# For each row (i.e. each country), fill NaNs in year columns with the row's mean
patents_filtered[year_cols] = patents_filtered[year_cols].apply(
    lambda row: row.fillna(row.mean()), axis=1
)

# %%
patents_filtered.isna().any()
# Out:
# Origin           False
# Origin (Code)    False
# Office           False
# Type             False
# 2015             False
# 2016             False
# 2017             False
# 2018             False
# 2019             False
# 2020             False
# dtype: bool

# %% [markdown]
# ## Melting the dataset

# %%
patents_filtered.head()
# Out:
#        Origin Origin (Code) Office   Type     2015     2016     2017     2018  \
# 5   Argentina            AR  Total  Total    856.0   1111.0    742.0    702.0
# 8     Austria            AT  Total  Total  11261.0  11118.0  10797.0  11280.0
# 15    Belgium            BE  Total  Total   8979.0   9485.0  10008.0  10437.0
# 24   Bulgaria            BG  Total  Total    467.0    389.0    380.0    394.0
# 30     Canada            CA  Total  Total  23258.0  22828.0  22252.0  22717.0
#
#        2019     2020
# 5     774.0   1215.0
# 8   11144.0  10645.0
# 15  10191.0   9665.0
# 24    380.0    517.0
# 30  23504.0  22172.0

# %%
df
# Out:
#      Unnamed: 0 Country Code  Year Country Name  \
# 0             1          ARG  2015    Argentina
# 1             2          ARG  2016    Argentina
# 2             3          ARG  2017    Argentina
# 3             4          ARG  2018    Argentina
# 4             5          ARG  2019    Argentina
# ..          ...          ...   ...          ...
# 253         254          UZB  2016   Uzbekistan
# 254         255          UZB  2017   Uzbekistan
# 255         256          UZB  2018   Uzbekistan
# 256         257          UZB  2019   Uzbekistan
# 257         258          UZB  2020   Uzbekistan
#
#      Researchers in R&D (per million people)  GDP per Capita (USD)  \
# 0                                 1231.48660          13679.626498
# 1                                 1260.70100          12699.962314
# 2                                 1212.45730          14532.500931
# 3                                 1227.40420          11752.799892
# 4                                 1231.51710           9955.974787
# ..                                       ...                   ...
# 253                                509.89435           2753.379514
# 254                                499.59238           2190.604116
# 255                                480.43228           1813.085308
# 256                                421.46490           2041.384807
# 257                                426.82077           1978.280519
#
#      Research and development expenditure (% of GDP)  \
# 0                                            0.62262
# 1                                            0.55815
# 2                                            0.55631
# 3                                            0.48830
# 4                                            0.47813
# ..                                               ...
# 253                                          0.17238
# 254                                          0.14834
# 255                                          0.12394
# 256                                          0.11306
# 257                                          0.13850
#
#      Unemployemnt total (% of total labor force)
# 0                                           7.579
# 1                                           8.085
# 2                                           8.347
# 3                                           9.220
# 4                                           9.843
# ..                                            ...
# 253                                         5.160
# 254                                         5.830
# 255                                         5.389
# 256                                         4.932
# 257                                         5.293
#
# [258 rows x 8 columns]

# %%
# Melt the patents dataframe
patents_long = patents_filtered.melt(
    id_vars=['Origin', 'Origin (Code)', 'Office', 'Type'],
    value_vars=['2015', '2016', '2017', '2018', '2019', '2020'],
    var_name='Year',
    value_name='Patent_Applications'
)

# %%
patents_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Origin               240 non-null    object
#  1   Origin (Code)        240 non-null    object
#  2   Office               240 non-null    object
#  3   Type                 240 non-null    object
#  4   Year                 240 non-null    object
#  5   Patent_Applications  240 non-null    float64
# dtypes: float64(1), object(5)
# memory usage: 11.4+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 8 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Unnamed: 0                                       258 non-null    int64
#  1   Country Code                                     258 non-null    object
#  2   Year                                             258 non-null    int64
#  3   Country Name                                     258 non-null    object
#  4   Researchers in R&D (per million people)          258 non-null    float64
#  5   GDP per Capita (USD)                             258 non-null    float64
#  6   Research and development expenditure (% of GDP)  258 non-null    float64
#  7   Unemployemnt total (% of total labor force)      258 non-null    float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 16.3+ KB

# %%
df['Year'] = df['Year'].astype(str)

# %%
df.rename(columns={'Country Name': 'Origin'}, inplace=True)

# %%
panel = pd.merge(
    patents_long,
    df,
    on=['Origin', 'Year'],
    how='left'
)
panel = panel.drop(columns = ['Origin (Code)', 'Office', 'Type', 'Country Code'])
panel
# Out:
#             Origin  Year  Patent_Applications  Unnamed: 0  \
# 0        Argentina  2015                856.0           1
# 1          Austria  2015              11261.0           7
# 2          Belgium  2015               8979.0          13
# 3         Bulgaria  2015                467.0          19
# 4           Canada  2015              23258.0          25
# ..             ...   ...                  ...         ...
# 235         Turkey  2020               9353.0         234
# 236        Ukraine  2020               1654.0         240
# 237  United States  2020             470131.0         252
# 238        Uruguay  2020                 94.0         246
# 239     Uzbekistan  2020                379.0         258
#
#      Researchers in R&D (per million people)  GDP per Capita (USD)  \
# 0                                 1231.48660          13679.626498
# 1                                 5074.43000          43915.228021
# 2                                 4741.86040          40893.804538
# 3                                 1939.14420           7078.860323
# 4                                 4582.37940          43594.194105
# ..                                       ...                   ...
# 235                               1786.51710           8638.739038
# 236                                846.24850           3709.769287
# 237                               4451.78120          64411.373178
# 238                                813.23790          15789.685742
# 239                                426.82077           1978.280519
#
#      Research and development expenditure (% of GDP)  \
# 0                                            0.62262
# 1                                            3.04969
# 2                                            2.42817
# 3                                            0.94947
# 4                                            1.69359
# ..                                               ...
# 235                                          1.36748
# 236                                          0.40318
# 237                                          3.42467
# 238                                          0.67468
# 239                                          0.13850
#
#      Unemployemnt total (% of total labor force)
# 0                                           7.579
# 1                                           5.802
# 2                                           8.482
# 3                                           9.143
# 4                                           6.945
# ..                                            ...
# 235                                        13.148
# 236                                         9.475
# 237                                         8.055
# 238                                        10.413
# 239                                         5.293
#
# [240 rows x 8 columns]

# %% [markdown]
# ## Final panel dataset containing Sasha's macro features + dependent variable
# 3 countries were dropped as the patents data was mostly unavailable for them

# %%
panel = panel.drop(columns = 'Unnamed: 0')
panel
# Out:
#             Origin  Year  Patent_Applications  \
# 0        Argentina  2015                856.0
# 1          Austria  2015              11261.0
# 2          Belgium  2015               8979.0
# 3         Bulgaria  2015                467.0
# 4           Canada  2015              23258.0
# ..             ...   ...                  ...
# 235         Turkey  2020               9353.0
# 236        Ukraine  2020               1654.0
# 237  United States  2020             470131.0
# 238        Uruguay  2020                 94.0
# 239     Uzbekistan  2020                379.0
#
#      Researchers in R&D (per million people)  GDP per Capita (USD)  \
# 0                                 1231.48660          13679.626498
# 1                                 5074.43000          43915.228021
# 2                                 4741.86040          40893.804538
# 3                                 1939.14420           7078.860323
# 4                                 4582.37940          43594.194105
# ..                                       ...                   ...
# 235                               1786.51710           8638.739038
# 236                                846.24850           3709.769287
# 237                               4451.78120          64411.373178
# 238                                813.23790          15789.685742
# 239                                426.82077           1978.280519
#
#      Research and development expenditure (% of GDP)  \
# 0                                            0.62262
# 1                                            3.04969
# 2                                            2.42817
# 3                                            0.94947
# 4                                            1.69359
# ..                                               ...
# 235                                          1.36748
# 236                                          0.40318
# 237                                          3.42467
# 238                                          0.67468
# 239                                          0.13850
#
#      Unemployemnt total (% of total labor force)
# 0                                           7.579
# 1                                           5.802
# 2                                           8.482
# 3                                           9.143
# 4                                           6.945
# ..                                            ...
# 235                                        13.148
# 236                                         9.475
# 237                                         8.055
# 238                                        10.413
# 239                                         5.293
#
# [240 rows x 7 columns]

# %%
print(panel['Origin'].unique())
len(panel['Origin'].unique())
# Out:
# ['Argentina' 'Austria' 'Belgium' 'Bulgaria' 'Canada' 'China' 'Croatia'
#  'Cyprus' 'Czechia' 'Denmark' 'Estonia' 'Finland' 'France' 'Georgia'
#  'Germany' 'Hungary' 'Ireland' 'Italy' 'Japan' 'Kazakhstan' 'Latvia'
#  'Lithuania' 'Luxembourg' 'Mexico' 'Netherlands' 'Panama' 'Poland'
#  'Portugal' 'Romania' 'Russia' 'Serbia' 'Singapore' 'Slovakia' 'Spain'
#  'Thailand' 'Turkey' 'Ukraine' 'United States' 'Uruguay' 'Uzbekistan']
# 40

# %%
pip install pycountry
# Out:
# Requirement already satisfied: pycountry in c:\users\grzes\downloads\econometrics_projects_codes\.venv\lib\site-packages (24.6.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pycountry

# Define a function to get the 3-letter country code
def get_country_code(country_name):
    try:
        return pycountry.countries.lookup(country_name).alpha_3
    except LookupError:
        return None  # or you can put 'XXX' or anything for not found

# Create the new column
panel['Country Code'] = panel['Origin'].apply(get_country_code)

# %%
panel['Country Code'].unique()
# Out:
# array(['ARG', 'AUT', 'BEL', 'BGR', 'CAN', 'CHN', 'HRV', 'CYP', 'CZE',
#        'DNK', 'EST', 'FIN', 'FRA', 'GEO', 'DEU', 'HUN', 'IRL', 'ITA',
#        'JPN', 'KAZ', 'LVA', 'LTU', 'LUX', 'MEX', 'NLD', 'PAN', 'POL',
#        'PRT', 'ROU', None, 'SRB', 'SGP', 'SVK', 'ESP', 'THA', 'UKR',
#        'USA', 'URY', 'UZB'], dtype=object)

# %%
missing_codes = panel[panel['Country Code'].isnull()]
missing_codes
# Out:
#      Origin  Year  Patent_Applications  \
# 29   Russia  2015              31648.0
# 35   Turkey  2015               6615.0
# 69   Russia  2016              29373.0
# 75   Turkey  2016               7583.0
# 109  Russia  2017              25260.0
# 115  Turkey  2017              10028.0
# 149  Russia  2018              27689.0
# 155  Turkey  2018               8609.0
# 189  Russia  2019              26535.0
# 195  Turkey  2019               9290.0
# 229  Russia  2020              26945.0
# 235  Turkey  2020               9353.0
#
#      Researchers in R&D (per million people)  GDP per Capita (USD)  \
# 29                                 3109.7632           9277.713867
# 35                                 1205.0807          11049.995110
# 69                                 2959.9658           8663.158203
# 75                                 1246.8931          10970.045895
# 109                                2825.5396          10658.913086
# 115                                1369.3460          10695.550196
# 149                                2787.2463          11211.887695
# 155                                1530.9047           9568.835063
# 189                                2749.4854          11447.701172
# 195                                1629.7324           9215.440499
# 229                                2724.9072          10108.327148
# 235                                1786.5171           8638.739038
#
#      Research and development expenditure (% of GDP)  \
# 29                                           1.10085
# 35                                           0.96732
# 69                                           1.10238
# 75                                           1.11979
# 109                                          1.10967
# 115                                          1.17632
# 149                                          0.99002
# 155                                          1.27093
# 189                                          1.03531
# 195                                          1.31960
# 229                                          1.09099
# 235                                          1.36748
#
#      Unemployemnt total (% of total labor force)  Country Code
# 29                                          5.615         None
# 35                                         10.304         None
# 69                                          5.591         None
# 75                                         10.899         None
# 109                                         5.238         None
# 115                                        10.919         None
# 149                                         4.871         None
# 155                                        10.956         None
# 189                                         4.513         None
# 195                                        13.730         None
# 229                                         5.620         None
# 235                                        13.148         None

# %%
panel.loc[panel['Origin'] == 'Russia', 'Country Code'] = panel.loc[panel['Origin'] == 'Russia', 'Country Code'].fillna('RUS')

# %%
panel.loc[panel['Origin'] == 'Turkey', 'Country Code'] = panel.loc[panel['Origin'] == 'Turkey', 'Country Code'].fillna('TUR')

# %%
panel['Country Code'].unique()
# Out:
# array(['ARG', 'AUT', 'BEL', 'BGR', 'CAN', 'CHN', 'HRV', 'CYP', 'CZE',
#        'DNK', 'EST', 'FIN', 'FRA', 'GEO', 'DEU', 'HUN', 'IRL', 'ITA',
#        'JPN', 'KAZ', 'LVA', 'LTU', 'LUX', 'MEX', 'NLD', 'PAN', 'POL',
#        'PRT', 'ROU', 'RUS', 'SRB', 'SGP', 'SVK', 'ESP', 'THA', 'TUR',
#        'UKR', 'USA', 'URY', 'UZB'], dtype=object)

# %%
panel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 8 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Origin                                           240 non-null    object
#  1   Year                                             240 non-null    object
#  2   Patent_Applications                              240 non-null    float64
#  3   Researchers in R&D (per million people)          240 non-null    float64
#  4   GDP per Capita (USD)                             240 non-null    float64
#  5   Research and development expenditure (% of GDP)  240 non-null    float64
#  6   Unemployemnt total (% of total labor force)      240 non-null    float64
#  7   Country Code                                     240 non-null    object
# dtypes: float64(5), object(3)
# memory usage: 15.1+ KB

# %%
panel['Year'] = panel['Year'].astype(int)

# %% [markdown]
# We have our panel dataset for period 2015-2020. Now, we can try to add independent variables such as first fillings, education, STEM graduates/capacities, Transfer Ratios*, Export Share, change in GDP. Actually - the variables that were used in the literature

# %%
indicators = pd.read_csv('indicator-data/indicators.csv')
indicators
# Out:
#          indicatorId                                               name  \
# 0     FOSGP.5T8.F600  Percentage of graduates from tertiary educatio...
# 1     FOSGP.5T8.F700  Percentage of graduates from tertiary educatio...
# 2           MENF.5T8  Net flow of internationally mobile students (i...
# 3  NY.GDP.MKTP.KD.ZG                              GDP growth (annual %)
# 4        SP.POP.GROW                       Population growth (annual %)
# 5         XGDP.FFNTR  Expenditure on education (public, private, int...
#
#                        theme lastDataUpdate   lastDataUpdateDescription  \
# 0                  EDUCATION     2025-02-23  February 2025 Data Release
# 1                  EDUCATION     2025-02-23  February 2025 Data Release
# 2                  EDUCATION     2025-02-23  February 2025 Data Release
# 3  DEMOGRAPHIC_SOCIOECONOMIC     2025-02-23  February 2025 Data Release
# 4  DEMOGRAPHIC_SOCIOECONOMIC     2025-02-23  February 2025 Data Release
# 5                  EDUCATION     2025-02-23  February 2025 Data Release
#
#    dataAvailability.totalRecordCount  dataAvailability.timeLine.min  \
# 0                               1813                           1998
# 1                               1810                           1998
# 2                               2425                           1998
# 3                               9937                           1970
# 4                              11641                           1970
# 5                                333                           2005
#
#    dataAvailability.timeLine.max dataAvailability.geoUnits.types  \
# 0                           2024                        NATIONAL
# 1                           2024                        NATIONAL
# 2                           2022                        NATIONAL
# 3                           2023                        NATIONAL
# 4                           2023                        NATIONAL
# 5                           2023                        NATIONAL
#
#                                      disaggregations  glossaryTerms
# 0                  EduLvl:Tertiary, EduField:InfComm         2115.0
# 1                EduLvl:Tertiary, EduField:EngManCon         2115.0
# 2                                                NaN         3238.0
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# 5  FundingSource:Private, FundingSource:Public, F...         2150.0

# %%
data = pd.read_csv('indicator-data/data.csv')
data.head()
# Out:
#       indicatorId geoUnit  year    value qualifier magnitude
# 0  FOSGP.5T8.F600     ABW  2015  0.00000       NaN       NIL
# 1  FOSGP.5T8.F600     ABW  2016  0.00000       NaN       NIL
# 2  FOSGP.5T8.F600     AFG  2020  4.58943       NaN       NaN
# 3  FOSGP.5T8.F600     AGO  2015  4.74076       NaN       NaN
# 4  FOSGP.5T8.F600     ALB  2015  5.05416       NaN       NaN

# %%
data['geoUnit'].unique()
# Out:
# array(['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'AUS',
#        'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA', 'BGD', 'BGR', 'BHR',
#        'BIH', 'BLR', 'BLZ', 'BMU', 'BRA', 'BRN', 'BWA', 'CAN', 'CHE',
#        'CHL', 'CMR', 'COD', 'COG', 'COL', 'CPV', 'CRI', 'CUB', 'CYP',
#        'CZE', 'DEU', 'DNK', 'DOM', 'DZA', 'ECU', 'EGY', 'ERI', 'ESP',
#        'EST', 'FIN', 'FJI', 'FRA', 'GBR', 'GEO', 'GHA', 'GIB', 'GRC',
#        'GRD', 'GTM', 'HND', 'HRV', 'HUN', 'IDN', 'IND', 'IRL', 'IRN',
#        'ISL', 'ISR', 'ITA', 'JOR', 'KAZ', 'KGZ', 'KHM', 'KOR', 'LAO',
#        'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA', 'MAC', 'MAR', 'MCO',
#        'MDA', 'MDG', 'MDV', 'MEX', 'MHL', 'MKD', 'MLT', 'MMR', 'MNE',
#        'MNG', 'MOZ', 'MRT', 'MSR', 'MUS', 'MYS', 'NAM', 'NER', 'NIU',
#        'NLD', 'NOR', 'NZL', 'OMN', 'PAN', 'PER', 'PHL', 'POL', 'PRI',
#        'PRK', 'PRT', 'PSE', 'QAT', 'ROU', 'RUS', 'RWA', 'SAU', 'SDN',
#        'SGP', 'SLV', 'SRB', 'SVK', 'SVN', 'SWE', 'SWZ', 'SXM', 'SYC',
#        'SYR', 'TCD', 'THA', 'TJK', 'TKM', 'TTO', 'TUN', 'TUR', 'UKR',
#        'URY', 'USA', 'UZB', 'VNM', 'WSM', 'ZAF', 'ZWE', 'VGB', 'CHN',
#        'CIV', 'GIN', 'HKG', 'JAM', 'JPN', 'KEN', 'LBN', 'LCA', 'MLI',
#        'SEN', 'SMR', 'TCA', 'TKL', 'TON', 'VCT', 'ASM', 'ATG', 'BHS',
#        'BOL', 'BRB', 'BTN', 'CAF', 'COM', 'CUW', 'CYM', 'DJI', 'DMA',
#        'ETH', 'FRO', 'FSM', 'GAB', 'GMB', 'GNB', 'GNQ', 'GRL', 'GUM',
#        'GUY', 'HTI', 'IMN', 'IRQ', 'KIR', 'KNA', 'KWT', 'LBR', 'LBY',
#        'MAF', 'MNP', 'MWI', 'NCL', 'NGA', 'NIC', 'NPL', 'NRU', 'PAK',
#        'PLW', 'PNG', 'PRY', 'PYF', 'SLB', 'SLE', 'SOM', 'SSD', 'STP',
#        'SUR', 'TGO', 'TLS', 'TUV', 'TZA', 'UGA', 'VIR', 'VUT', 'YEM',
#        'ZMB', 'ZZA', 'VEN'], dtype=object)

# %% [markdown]
# ## GDP growth

# %%
# NY.GDP.MKTP.KD.ZG
gdp_growth = data[data['indicatorId'] == 'NY.GDP.MKTP.KD.ZG']
gdp_growth
# Out:
#             indicatorId geoUnit  year    value qualifier magnitude
# 1817  NY.GDP.MKTP.KD.ZG     ABW  2015 -0.62363       NaN       NaN
# 1818  NY.GDP.MKTP.KD.ZG     ABW  2016  1.71962       NaN       NaN
# 1819  NY.GDP.MKTP.KD.ZG     ABW  2017  7.04853       NaN       NaN
# 1820  NY.GDP.MKTP.KD.ZG     ABW  2018  2.38173       NaN       NaN
# 1821  NY.GDP.MKTP.KD.ZG     ABW  2019 -2.30284       NaN       NaN
# ...                 ...     ...   ...      ...       ...       ...
# 3060  NY.GDP.MKTP.KD.ZG     ZWE  2020 -7.81695       NaN       NaN
# 3061  NY.GDP.MKTP.KD.ZG     ZZA  2017  2.57442       NaN       NaN
# 3062  NY.GDP.MKTP.KD.ZG     ZZA  2018  2.06645       NaN       NaN
# 3063  NY.GDP.MKTP.KD.ZG     ZZA  2019  2.36074       NaN       NaN
# 3064  NY.GDP.MKTP.KD.ZG     ZZA  2020 -8.46760       NaN       NaN
#
# [1248 rows x 6 columns]

# %%
gdp_growth = gdp_growth.drop(columns=['indicatorId', 'qualifier', 'magnitude'])
gdp_growth
# Out:
#      geoUnit  year    value
# 1817     ABW  2015 -0.62363
# 1818     ABW  2016  1.71962
# 1819     ABW  2017  7.04853
# 1820     ABW  2018  2.38173
# 1821     ABW  2019 -2.30284
# ...      ...   ...      ...
# 3060     ZWE  2020 -7.81695
# 3061     ZZA  2017  2.57442
# 3062     ZZA  2018  2.06645
# 3063     ZZA  2019  2.36074
# 3064     ZZA  2020 -8.46760
#
# [1248 rows x 3 columns]

# %%
# Rename 'geoUnit' to 'Country Code' in gdp_growth dataframe
gdp_growth.rename(columns={'geoUnit': 'Country Code'}, inplace=True)
gdp_growth.rename(columns={'year':'Year'}, inplace=True)

# Merge the two dataframes based on 'Country Code' and 'Year'
panel_merged = pd.merge(panel, gdp_growth, on=['Country Code', 'Year'], how='left')

# Check the merged dataframe
panel_merged.head()
# Out:
#       Origin  Year  Patent_Applications  \
# 0  Argentina  2015                856.0
# 1    Austria  2015              11261.0
# 2    Belgium  2015               8979.0
# 3   Bulgaria  2015                467.0
# 4     Canada  2015              23258.0
#
#    Researchers in R&D (per million people)  GDP per Capita (USD)  \
# 0                                1231.4866          13679.626498
# 1                                5074.4300          43915.228021
# 2                                4741.8604          40893.804538
# 3                                1939.1442           7078.860323
# 4                                4582.3794          43594.194105
#
#    Research and development expenditure (% of GDP)  \
# 0                                          0.62262
# 1                                          3.04969
# 2                                          2.42817
# 3                                          0.94947
# 4                                          1.69359
#
#    Unemployemnt total (% of total labor force)  Country Code    value
# 0                                         7.579          ARG  2.73116
# 1                                         5.802          AUT  1.01450
# 2                                         8.482          BEL  2.04146
# 3                                         9.143          BGR  3.39755
# 4                                         6.945          CAN  0.64997

# %%
panel_merged.rename(columns={'value':'gdp_growth'},inplace= True)

# %% [markdown]
# ## Population growth

# %%
# SP.POP.GROW
pop_growth = data[data['indicatorId'] == 'SP.POP.GROW']
pop_growth
# Out:
#       indicatorId geoUnit  year    value qualifier magnitude
# 3065  SP.POP.GROW     ABW  2015  0.63796       NaN       NaN
# 3066  SP.POP.GROW     ABW  2016  0.59006       NaN       NaN
# 3067  SP.POP.GROW     ABW  2017  0.53730       NaN       NaN
# 3068  SP.POP.GROW     ABW  2018  0.49480       NaN       NaN
# 3069  SP.POP.GROW     ABW  2019  0.45197       NaN       NaN
# ...           ...     ...   ...      ...       ...       ...
# 4356  SP.POP.GROW     ZZA  2016  0.93953       NaN       NaN
# 4357  SP.POP.GROW     ZZA  2017  0.90839       NaN       NaN
# 4358  SP.POP.GROW     ZZA  2018  1.22959       NaN       NaN
# 4359  SP.POP.GROW     ZZA  2019  1.27783       NaN       NaN
# 4360  SP.POP.GROW     ZZA  2020  1.00023       NaN       NaN
#
# [1296 rows x 6 columns]

# %%
pop_growth.rename(columns={'geoUnit':'Country Code','year':'Year','value':'pop_growth'}, inplace=True)
pop_growth = pop_growth.drop(columns=['indicatorId','qualifier', 'magnitude'])
pop_growth.head()
# Out:
# C:\Users\grzes\AppData\Local\Temp\ipykernel_21232\3843614035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pop_growth.rename(columns={'geoUnit':'Country Code','year':'Year','value':'pop_growth'}, inplace=True)
#      Country Code  Year  pop_growth
# 3065          ABW  2015     0.63796
# 3066          ABW  2016     0.59006
# 3067          ABW  2017     0.53730
# 3068          ABW  2018     0.49480
# 3069          ABW  2019     0.45197

# %%
panel_merged = pd.merge(panel_merged,pop_growth,on=['Country Code',"Year"],how = 'left')
panel_merged.head()
# Out:
#       Origin  Year  Patent_Applications  \
# 0  Argentina  2015                856.0
# 1    Austria  2015              11261.0
# 2    Belgium  2015               8979.0
# 3   Bulgaria  2015                467.0
# 4     Canada  2015              23258.0
#
#    Researchers in R&D (per million people)  GDP per Capita (USD)  \
# 0                                1231.4866          13679.626498
# 1                                5074.4300          43915.228021
# 2                                4741.8604          40893.804538
# 3                                1939.1442           7078.860323
# 4                                4582.3794          43594.194105
#
#    Research and development expenditure (% of GDP)  \
# 0                                          0.62262
# 1                                          3.04969
# 2                                          2.42817
# 3                                          0.94947
# 4                                          1.69359
#
#    Unemployemnt total (% of total labor force)  Country Code  gdp_growth  \
# 0                                         7.579          ARG     2.73116
# 1                                         5.802          AUT     1.01450
# 2                                         8.482          BEL     2.04146
# 3                                         9.143          BGR     3.39755
# 4                                         6.945          CAN     0.64997
#
#    pop_growth
# 0     1.07800
# 1     1.12099
# 2     0.57945
# 3    -0.63807
# 4     0.76030

# %% [markdown]
# ## Net_flow

# %%
# MENF.5T8
net_flow = data[data['indicatorId'] == 'MENF.5T8']
net_flow.rename(columns={'geoUnit':'Country Code','year':'Year','value':'net_flow'}, inplace=True)
net_flow = net_flow.drop(columns=['indicatorId','qualifier', 'magnitude'])
net_flow.head()
# Out:
# C:\Users\grzes\AppData\Local\Temp\ipykernel_21232\4150712398.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   net_flow.rename(columns={'geoUnit':'Country Code','year':'Year','value':'net_flow'}, inplace=True)
#      Country Code  Year  net_flow
# 1147          ABW  2015      99.0
# 1148          ABW  2016      89.0
# 1149          AFG  2020  -33310.0
# 1150          ALB  2018  -16791.0
# 1151          ALB  2019   -8850.0

# %%
panel_merged = pd.merge(panel_merged, net_flow, on=['Country Code','Year'],how='left')
panel_merged
# Out:
#             Origin  Year  Patent_Applications  \
# 0        Argentina  2015                856.0
# 1          Austria  2015              11261.0
# 2          Belgium  2015               8979.0
# 3         Bulgaria  2015                467.0
# 4           Canada  2015              23258.0
# ..             ...   ...                  ...
# 235         Turkey  2020               9353.0
# 236        Ukraine  2020               1654.0
# 237  United States  2020             470131.0
# 238        Uruguay  2020                 94.0
# 239     Uzbekistan  2020                379.0
#
#      Researchers in R&D (per million people)  GDP per Capita (USD)  \
# 0                                 1231.48660          13679.626498
# 1                                 5074.43000          43915.228021
# 2                                 4741.86040          40893.804538
# 3                                 1939.14420           7078.860323
# 4                                 4582.37940          43594.194105
# ..                                       ...                   ...
# 235                               1786.51710           8638.739038
# 236                                846.24850           3709.769287
# 237                               4451.78120          64411.373178
# 238                                813.23790          15789.685742
# 239                                426.82077           1978.280519
#
#      Research and development expenditure (% of GDP)  \
# 0                                            0.62262
# 1                                            3.04969
# 2                                            2.42817
# 3                                            0.94947
# 4                                            1.69359
# ..                                               ...
# 235                                          1.36748
# 236                                          0.40318
# 237                                          3.42467
# 238                                          0.67468
# 239                                          0.13850
#
#      Unemployemnt total (% of total labor force)  Country Code  gdp_growth  \
# 0                                           7.579          ARG     2.73116
# 1                                           5.802          AUT     1.01450
# 2                                           8.482          BEL     2.04146
# 3                                           9.143          BGR     3.39755
# 4                                           6.945          CAN     0.64997
# ..                                            ...          ...         ...
# 235                                        13.148          TUR     1.85984
# 236                                         9.475          UKR    -3.75280
# 237                                         8.055          USA    -2.21347
# 238                                        10.413          URY    -7.38010
# 239                                         5.293          UZB     1.99559
#
#      pop_growth       net_flow
# 0       1.07800            NaN
# 1       1.12099   50254.347656
# 2       0.57945   42932.000000
# 3      -0.63807  -12491.000000
# 4       0.76030  121634.000000
# ..          ...            ...
# 235     0.97039  133756.000000
# 236    -0.60161   -8580.000000
# 237     0.96900  848728.187500
# 238     0.01974   -2530.000000
# 239     1.92213            NaN
#
# [240 rows x 11 columns]

# %% [markdown]
# ## Expenditure on education

# %%
# XGDP.FFNTR	
edu_exp = data[data['indicatorId'] == 'XGDP.FFNTR']
edu_exp.head()
# Out:
#      indicatorId geoUnit  year     value qualifier magnitude
# 4361  XGDP.FFNTR     AND  2015  3.801682       NaN       NaN
# 4362  XGDP.FFNTR     AND  2016  3.808137       NaN       NaN
# 4363  XGDP.FFNTR     AND  2017  3.762174       NaN       NaN
# 4364  XGDP.FFNTR     AND  2018  3.796796       NaN       NaN
# 4365  XGDP.FFNTR     AND  2019  3.729350       NaN       NaN

# %%
edu_exp.rename(columns={'geoUnit':'Country Code','year':'Year','value':'edu_exp'}, inplace=True)
edu_exp = edu_exp.drop(columns=['indicatorId','qualifier', 'magnitude'])
edu_exp.head()
# Out:
# C:\Users\grzes\AppData\Local\Temp\ipykernel_21232\1999689733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edu_exp.rename(columns={'geoUnit':'Country Code','year':'Year','value':'edu_exp'}, inplace=True)
#      Country Code  Year   edu_exp
# 4361          AND  2015  3.801682
# 4362          AND  2016  3.808137
# 4363          AND  2017  3.762174
# 4364          AND  2018  3.796796
# 4365          AND  2019  3.729350

# %%
panel_merged = pd.merge(panel_merged, edu_exp, on=['Country Code','Year'],how='left')
panel_merged
# Out:
#             Origin  Year  Patent_Applications  \
# 0        Argentina  2015                856.0
# 1          Austria  2015              11261.0
# 2          Belgium  2015               8979.0
# 3         Bulgaria  2015                467.0
# 4           Canada  2015              23258.0
# ..             ...   ...                  ...
# 235         Turkey  2020               9353.0
# 236        Ukraine  2020               1654.0
# 237  United States  2020             470131.0
# 238        Uruguay  2020                 94.0
# 239     Uzbekistan  2020                379.0
#
#      Researchers in R&D (per million people)  GDP per Capita (USD)  \
# 0                                 1231.48660          13679.626498
# 1                                 5074.43000          43915.228021
# 2                                 4741.86040          40893.804538
# 3                                 1939.14420           7078.860323
# 4                                 4582.37940          43594.194105
# ..                                       ...                   ...
# 235                               1786.51710           8638.739038
# 236                                846.24850           3709.769287
# 237                               4451.78120          64411.373178
# 238                                813.23790          15789.685742
# 239                                426.82077           1978.280519
#
#      Research and development expenditure (% of GDP)  \
# 0                                            0.62262
# 1                                            3.04969
# 2                                            2.42817
# 3                                            0.94947
# 4                                            1.69359
# ..                                               ...
# 235                                          1.36748
# 236                                          0.40318
# 237                                          3.42467
# 238                                          0.67468
# 239                                          0.13850
#
#      Unemployemnt total (% of total labor force)  Country Code  gdp_growth  \
# 0                                           7.579          ARG     2.73116
# 1                                           5.802          AUT     1.01450
# 2                                           8.482          BEL     2.04146
# 3                                           9.143          BGR     3.39755
# 4                                           6.945          CAN     0.64997
# ..                                            ...          ...         ...
# 235                                        13.148          TUR     1.85984
# 236                                         9.475          UKR    -3.75280
# 237                                         8.055          USA    -2.21347
# 238                                        10.413          URY    -7.38010
# 239                                         5.293          UZB     1.99559
#
#      pop_growth       net_flow   edu_exp
# 0       1.07800            NaN       NaN
# 1       1.12099   50254.347656  5.848230
# 2       0.57945   42932.000000  7.123384
# 3      -0.63807  -12491.000000       NaN
# 4       0.76030  121634.000000  5.815642
# ..          ...            ...       ...
# 235     0.97039  133756.000000       NaN
# 236    -0.60161   -8580.000000       NaN
# 237     0.96900  848728.187500  7.402097
# 238     0.01974   -2530.000000       NaN
# 239     1.92213            NaN       NaN
#
# [240 rows x 12 columns]

# %% [markdown]
# ## STEM graduates

# %%
# Percentage of graduates from tertiary education graduating from Information and Communication Technologies programmes
# FOSGP.5T8.F600	
informatics = data[data['indicatorId'] == 'FOSGP.5T8.F600']
informatics.rename(columns={'geoUnit':'Country Code','year':'Year','value':'edu_exp'}, inplace=True)
informatics = informatics.drop(columns=['indicatorId','qualifier', 'magnitude'])
informatics.head()
# Out:
# C:\Users\grzes\AppData\Local\Temp\ipykernel_21232\2322452174.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   informatics.rename(columns={'geoUnit':'Country Code','year':'Year','value':'edu_exp'}, inplace=True)
#   Country Code  Year  edu_exp
# 0          ABW  2015  0.00000
# 1          ABW  2016  0.00000
# 2          AFG  2020  4.58943
# 3          AGO  2015  4.74076
# 4          ALB  2015  5.05416

# %%
informatics.rename(columns={'edu_exp': 'inf_num'}, inplace=True)

# %%
informatics.head()
# Out:
#   Country Code  Year  inf_num
# 0          ABW  2015  0.00000
# 1          ABW  2016  0.00000
# 2          AFG  2020  4.58943
# 3          AGO  2015  4.74076
# 4          ALB  2015  5.05416

# %%
# Percentage of graduates from tertiary education graduating from Engineering, Manufacturing and Construction  programmes, both sexes
engineers = data[data['indicatorId'] == 'FOSGP.5T8.F700']
engineers.rename(columns={'geoUnit':'Country Code','year':'Year','value':'eng_num'}, inplace=True)
engineers = engineers.drop(columns=['indicatorId','qualifier', 'magnitude'])
engineers.head()
# Out:
# C:\Users\grzes\AppData\Local\Temp\ipykernel_21232\3637763681.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   engineers.rename(columns={'geoUnit':'Country Code','year':'Year','value':'eng_num'}, inplace=True)
#     Country Code  Year  eng_num
# 573          ABW  2015  0.00000
# 574          ABW  2016  0.00000
# 575          AFG  2020  5.84207
# 576          AGO  2015  4.56635
# 577          ALB  2015  7.80828

# %%
# Additionally, let's read one more feature
stats = pd.read_csv('data2.csv')
stats.rename(columns={'geoUnit':'Country Code','year':'Year','value':'stats_num'}, inplace=True)
stats = stats.drop(columns=['indicatorId','qualifier', 'magnitude'])
stats.head()
# Out:
#   Country Code  Year  stats_num
# 0          ABW  2015    0.00000
# 1          ABW  2016    2.22222
# 2          AFG  2020    0.81362
# 3          AGO  2015    2.70335
# 4          ALB  2015    5.28268

# %%
# Let's add the values to obtain the total number of STEM students
step1 = pd.merge(informatics,engineers,on=['Country Code','Year'],how='left')
step1.head()
# Out:
#   Country Code  Year  inf_num  eng_num
# 0          ABW  2015  0.00000  0.00000
# 1          ABW  2016  0.00000  0.00000
# 2          AFG  2020  4.58943  5.84207
# 3          AGO  2015  4.74076  4.56635
# 4          ALB  2015  5.05416  7.80828

# %%
step2 = pd.merge(step1,stats,on=['Country Code','Year'],how='left')
step2.head()
# Out:
#   Country Code  Year  inf_num  eng_num  stats_num
# 0          ABW  2015  0.00000  0.00000    0.00000
# 1          ABW  2016  0.00000  0.00000    2.22222
# 2          AFG  2020  4.58943  5.84207    0.81362
# 3          AGO  2015  4.74076  4.56635    2.70335
# 4          ALB  2015  5.05416  7.80828    5.28268

# %%
step2['stem_graduates'] = step2['eng_num'] + step2['inf_num'] + step2['stats_num']
step2 = step2.drop(columns=['inf_num','eng_num','stats_num'])
step2.head()
# Out:
#   Country Code  Year  stem_graduates
# 0          ABW  2015         0.00000
# 1          ABW  2016         2.22222
# 2          AFG  2020        11.24512
# 3          AGO  2015        12.01046
# 4          ALB  2015        18.14512

# %% [markdown]
# ## We finished the dataset. Let's look at its missing values

# %%
panel_merged = pd.merge(panel_merged,step2,on=['Country Code','Year'],how='left')
panel_merged.head()
# Out:
#       Origin  Year  Patent_Applications  \
# 0  Argentina  2015                856.0
# 1    Austria  2015              11261.0
# 2    Belgium  2015               8979.0
# 3   Bulgaria  2015                467.0
# 4     Canada  2015              23258.0
#
#    Researchers in R&D (per million people)  GDP per Capita (USD)  \
# 0                                1231.4866          13679.626498
# 1                                5074.4300          43915.228021
# 2                                4741.8604          40893.804538
# 3                                1939.1442           7078.860323
# 4                                4582.3794          43594.194105
#
#    Research and development expenditure (% of GDP)  \
# 0                                          0.62262
# 1                                          3.04969
# 2                                          2.42817
# 3                                          0.94947
# 4                                          1.69359
#
#    Unemployemnt total (% of total labor force)  Country Code  gdp_growth  \
# 0                                         7.579          ARG     2.73116
# 1                                         5.802          AUT     1.01450
# 2                                         8.482          BEL     2.04146
# 3                                         9.143          BGR     3.39755
# 4                                         6.945          CAN     0.64997
#
#    pop_growth       net_flow   edu_exp  stem_graduates
# 0     1.07800            NaN       NaN             NaN
# 1     1.12099   50254.347656  5.848230       29.271710
# 2     0.57945   42932.000000  7.123384       17.382830
# 3    -0.63807  -12491.000000       NaN       20.793081
# 4     0.76030  121634.000000  5.815642       20.027500

# %%
panel_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 13 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Origin                                           240 non-null    object
#  1   Year                                             240 non-null    int64
#  2   Patent_Applications                              240 non-null    float64
#  3   Researchers in R&D (per million people)          240 non-null    float64
#  4   GDP per Capita (USD)                             240 non-null    float64
#  5   Research and development expenditure (% of GDP)  240 non-null    float64
#  6   Unemployemnt total (% of total labor force)      240 non-null    float64
#  7   Country Code                                     240 non-null    object
#  8   gdp_growth                                       240 non-null    float64
#  9   pop_growth                                       240 non-null    float64
#  10  net_flow                                         221 non-null    float64
#  11  edu_exp                                          109 non-null    float64
#  12  stem_graduates                                   192 non-null    float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 24.5+ KB

# %%
# panel_merged.to_csv('panel_merged.csv', index=False)

# %%
panel_merged[panel_merged['edu_exp'].isna()]['Origin'].value_counts()
# Out:
# Origin
# Argentina     6
# China         6
# France        6
# Estonia       6
# Kazakhstan    6
# Japan         6
# Georgia       6
# Hungary       6
# Mexico        6
# Singapore     6
# Serbia        6
# Panama        6
# Ukraine       6
# Uruguay       6
# Uzbekistan    6
# Thailand      6
# Germany       5
# Russia        5
# Croatia       5
# Canada        5
# Turkey        5
# Ireland       3
# Bulgaria      2
# Denmark       1
# Portugal      1
# Luxembourg    1
# Slovakia      1
# Cyprus        1
# Name: count, dtype: int64

# %%
# Dobra, education expenses do dropniecia

# %%
export = pd.read_csv('export_share_data.csv')
export
# Out:
#       IndicatorCode               IndicatorName             VariableName  \
# 0                 4  Share of exports in GDP, %  Share of exports in GDP
# 1                 4  Share of exports in GDP, %  Share of exports in GDP
# 2                 4  Share of exports in GDP, %  Share of exports in GDP
# 3                 4  Share of exports in GDP, %  Share of exports in GDP
# 4                 4  Share of exports in GDP, %  Share of exports in GDP
# ...             ...                         ...                      ...
# 1115              4  Share of exports in GDP, %  Share of exports in GDP
# 1116              4  Share of exports in GDP, %  Share of exports in GDP
# 1117              4  Share of exports in GDP, %  Share of exports in GDP
# 1118              4  Share of exports in GDP, %  Share of exports in GDP
# 1119              4  Share of exports in GDP, %  Share of exports in GDP
#
#      MeasurementName  CountryCode Alpha3Code CountryName  PeriodCode Value  \
# 0            Percent            8        ALB     Albania        2005  23.0
# 1            Percent            8        ALB     Albania        2006  25.2
# 2            Percent            8        ALB     Albania        2007  28.2
# 3            Percent            8        ALB     Albania        2008  25.3
# 4            Percent            8        ALB     Albania        2009  25.2
# ...              ...          ...        ...         ...         ...   ...
# 1115         Percent          860        UZB  Uzbekistan        2020  21.9
# 1116         Percent          860        UZB  Uzbekistan        2021  21.3
# 1117         Percent          860        UZB  Uzbekistan        2022  24.3
# 1118         Percent          860        UZB  Uzbekistan        2023  23.7
# 1119         Percent          860        UZB  Uzbekistan        2024    ..
#
#       Unnamed: 9
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1115         NaN
# 1116         NaN
# 1117         NaN
# 1118         NaN
# 1119         NaN
#
# [1120 rows x 10 columns]

# %%
export.rename(columns={'Alpha3Code':'Origin'}, inplace= True)

# %%
export.rename(columns={'PeriodCode':'Year'}, inplace= True)

# %%
export
# Out:
#       IndicatorCode               IndicatorName             VariableName  \
# 0                 4  Share of exports in GDP, %  Share of exports in GDP
# 1                 4  Share of exports in GDP, %  Share of exports in GDP
# 2                 4  Share of exports in GDP, %  Share of exports in GDP
# 3                 4  Share of exports in GDP, %  Share of exports in GDP
# 4                 4  Share of exports in GDP, %  Share of exports in GDP
# ...             ...                         ...                      ...
# 1115              4  Share of exports in GDP, %  Share of exports in GDP
# 1116              4  Share of exports in GDP, %  Share of exports in GDP
# 1117              4  Share of exports in GDP, %  Share of exports in GDP
# 1118              4  Share of exports in GDP, %  Share of exports in GDP
# 1119              4  Share of exports in GDP, %  Share of exports in GDP
#
#      MeasurementName  CountryCode Origin CountryName  Year Value  Unnamed: 9
# 0            Percent            8    ALB     Albania  2005  23.0         NaN
# 1            Percent            8    ALB     Albania  2006  25.2         NaN
# 2            Percent            8    ALB     Albania  2007  28.2         NaN
# 3            Percent            8    ALB     Albania  2008  25.3         NaN
# 4            Percent            8    ALB     Albania  2009  25.2         NaN
# ...              ...          ...    ...         ...   ...   ...         ...
# 1115         Percent          860    UZB  Uzbekistan  2020  21.9         NaN
# 1116         Percent          860    UZB  Uzbekistan  2021  21.3         NaN
# 1117         Percent          860    UZB  Uzbekistan  2022  24.3         NaN
# 1118         Percent          860    UZB  Uzbekistan  2023  23.7         NaN
# 1119         Percent          860    UZB  Uzbekistan  2024    ..         NaN
#
# [1120 rows x 10 columns]

# %%
print(len(export["Origin"].unique()))
export["Origin"].unique()
# Out:
# 56
# array(['ALB', 'AND', 'ARM', 'AUT', 'AZE', 'BLR', 'BEL', 'BIH', 'BGR',
#        'CAN', 'HRV', 'CYP', 'CZE', 'DNK', 'EST', 'FIN', 'FRA', 'GEO',
#        'DEU', 'GRC', 'HUN', 'ISL', 'IRL', 'ISR', 'ITA', 'KAZ', 'KGZ',
#        'LVA', 'LIE', 'LTU', 'LUX', 'MLT', 'MCO', 'MNE', 'NLD', 'MKD',
#        'NOR', 'POL', 'PRT', 'MDA', 'ROU', 'RUS', 'SMR', 'SRB', 'SVK',
#        'SVN', 'ESP', 'SWE', 'CHE', 'TJK', 'TUR', 'TKM', 'UKR', 'GBR',
#        'USA', 'UZB'], dtype=object)

# %%
new_panel = panel_merged.merge(
    export[['Origin', 'Year', 'Value']],
    on=['Origin', 'Year'],
    how='left'
)

# %%
new_panel
# Out:
#             Origin  Year  Patent_Applications  \
# 0        Argentina  2015                856.0
# 1          Austria  2015              11261.0
# 2          Belgium  2015               8979.0
# 3         Bulgaria  2015                467.0
# 4           Canada  2015              23258.0
# ..             ...   ...                  ...
# 235         Turkey  2020               9353.0
# 236        Ukraine  2020               1654.0
# 237  United States  2020             470131.0
# 238        Uruguay  2020                 94.0
# 239     Uzbekistan  2020                379.0
#
#      Researchers in R&D (per million people)  GDP per Capita (USD)  \
# 0                                 1231.48660          13679.626498
# 1                                 5074.43000          43915.228021
# 2                                 4741.86040          40893.804538
# 3                                 1939.14420           7078.860323
# 4                                 4582.37940          43594.194105
# ..                                       ...                   ...
# 235                               1786.51710           8638.739038
# 236                                846.24850           3709.769287
# 237                               4451.78120          64411.373178
# 238                                813.23790          15789.685742
# 239                                426.82077           1978.280519
#
#      Research and development expenditure (% of GDP)  \
# 0                                            0.62262
# 1                                            3.04969
# 2                                            2.42817
# 3                                            0.94947
# 4                                            1.69359
# ..                                               ...
# 235                                          1.36748
# 236                                          0.40318
# 237                                          3.42467
# 238                                          0.67468
# 239                                          0.13850
#
#      Unemployemnt total (% of total labor force)  Country Code  gdp_growth  \
# 0                                           7.579          ARG     2.73116
# 1                                           5.802          AUT     1.01450
# 2                                           8.482          BEL     2.04146
# 3                                           9.143          BGR     3.39755
# 4                                           6.945          CAN     0.64997
# ..                                            ...          ...         ...
# 235                                        13.148          TUR     1.85984
# 236                                         9.475          UKR    -3.75280
# 237                                         8.055          USA    -2.21347
# 238                                        10.413          URY    -7.38010
# 239                                         5.293          UZB     1.99559
#
#      pop_growth       net_flow   edu_exp  stem_graduates Value
# 0       1.07800            NaN       NaN             NaN   NaN
# 1       1.12099   50254.347656  5.848230       29.271710   NaN
# 2       0.57945   42932.000000  7.123384       17.382830   NaN
# 3      -0.63807  -12491.000000       NaN       20.793081   NaN
# 4       0.76030  121634.000000  5.815642       20.027500   NaN
# ..          ...            ...       ...             ...   ...
# 235     0.97039  133756.000000       NaN       15.212980   NaN
# 236    -0.60161   -8580.000000       NaN       24.254510   NaN
# 237     0.96900  848728.187500  7.402097       19.553050   NaN
# 238     0.01974   -2530.000000       NaN       15.237220   NaN
# 239     1.92213            NaN       NaN       36.932010   NaN
#
# [240 rows x 14 columns]

# %%
new_panel = pd.merge(panel_merged,export,on=['Year','Origin'],how='left')
new_panel
# Out:
#             Origin  Year  Patent_Applications  \
# 0        Argentina  2015                856.0
# 1          Austria  2015              11261.0
# 2          Belgium  2015               8979.0
# 3         Bulgaria  2015                467.0
# 4           Canada  2015              23258.0
# ..             ...   ...                  ...
# 235         Turkey  2020               9353.0
# 236        Ukraine  2020               1654.0
# 237  United States  2020             470131.0
# 238        Uruguay  2020                 94.0
# 239     Uzbekistan  2020                379.0
#
#      Researchers in R&D (per million people)  GDP per Capita (USD)  \
# 0                                 1231.48660          13679.626498
# 1                                 5074.43000          43915.228021
# 2                                 4741.86040          40893.804538
# 3                                 1939.14420           7078.860323
# 4                                 4582.37940          43594.194105
# ..                                       ...                   ...
# 235                               1786.51710           8638.739038
# 236                                846.24850           3709.769287
# 237                               4451.78120          64411.373178
# 238                                813.23790          15789.685742
# 239                                426.82077           1978.280519
#
#      Research and development expenditure (% of GDP)  \
# 0                                            0.62262
# 1                                            3.04969
# 2                                            2.42817
# 3                                            0.94947
# 4                                            1.69359
# ..                                               ...
# 235                                          1.36748
# 236                                          0.40318
# 237                                          3.42467
# 238                                          0.67468
# 239                                          0.13850
#
#      Unemployemnt total (% of total labor force)  Country Code  gdp_growth  \
# 0                                           7.579          ARG     2.73116
# 1                                           5.802          AUT     1.01450
# 2                                           8.482          BEL     2.04146
# 3                                           9.143          BGR     3.39755
# 4                                           6.945          CAN     0.64997
# ..                                            ...          ...         ...
# 235                                        13.148          TUR     1.85984
# 236                                         9.475          UKR    -3.75280
# 237                                         8.055          USA    -2.21347
# 238                                        10.413          URY    -7.38010
# 239                                         5.293          UZB     1.99559
#
#      pop_growth  ...   edu_exp  stem_graduates  IndicatorCode  IndicatorName  \
# 0       1.07800  ...       NaN             NaN            NaN            NaN
# 1       1.12099  ...  5.848230       29.271710            NaN            NaN
# 2       0.57945  ...  7.123384       17.382830            NaN            NaN
# 3      -0.63807  ...       NaN       20.793081            NaN            NaN
# 4       0.76030  ...  5.815642       20.027500            NaN            NaN
# ..          ...  ...       ...             ...            ...            ...
# 235     0.97039  ...       NaN       15.212980            NaN            NaN
# 236    -0.60161  ...       NaN       24.254510            NaN            NaN
# 237     0.96900  ...  7.402097       19.553050            NaN            NaN
# 238     0.01974  ...       NaN       15.237220            NaN            NaN
# 239     1.92213  ...       NaN       36.932010            NaN            NaN
#
#     VariableName MeasurementName CountryCode  CountryName Value Unnamed: 9
# 0            NaN             NaN         NaN          NaN   NaN        NaN
# 1            NaN             NaN         NaN          NaN   NaN        NaN
# 2            NaN             NaN         NaN          NaN   NaN        NaN
# 3            NaN             NaN         NaN          NaN   NaN        NaN
# 4            NaN             NaN         NaN          NaN   NaN        NaN
# ..           ...             ...         ...          ...   ...        ...
# 235          NaN             NaN         NaN          NaN   NaN        NaN
# 236          NaN             NaN         NaN          NaN   NaN        NaN
# 237          NaN             NaN         NaN          NaN   NaN        NaN
# 238          NaN             NaN         NaN          NaN   NaN        NaN
# 239          NaN             NaN         NaN          NaN   NaN        NaN
#
# [240 rows x 21 columns]

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
export2 = pd.read_excel('WITS-Country-Timeseries.xlsx')
export2
# Out:
#     Country Name                            Indicator Name       2015  \
# 0    Afghanistan  Exports of goods and services (% of GDP)        NaN
# 1        Albania  Exports of goods and services (% of GDP)  27.267391
# 2        Algeria  Exports of goods and services (% of GDP)  23.171778
# 3        Andorra  Exports of goods and services (% of GDP)        NaN
# 4         Angola  Exports of goods and services (% of GDP)  29.754598
# ..           ...                                       ...        ...
# 188    Venezuela  Exports of goods and services (% of GDP)        NaN
# 189      Vietnam  Exports of goods and services (% of GDP)  72.922848
# 190        Yemen  Exports of goods and services (% of GDP)  18.321800
# 191       Zambia  Exports of goods and services (% of GDP)  37.138526
# 192     Zimbabwe  Exports of goods and services (% of GDP)  19.160176
#
#           2016       2017       2018       2019       2020
# 0          NaN        NaN        NaN        NaN        NaN
# 1    28.977899  31.569798  31.571954  31.304270  22.657790
# 2    20.872485  22.632232  25.861151  22.714404  17.469840
# 3          NaN        NaN        NaN        NaN        NaN
# 4    28.124485  29.004102  40.836290  40.790755  38.038274
# ..         ...        ...        ...        ...        ...
# 188        NaN        NaN        NaN        NaN        NaN
# 189  74.107286  81.762516  84.423458  85.157590  84.381595
# 190   5.977269   8.709109   6.056570        NaN        NaN
# 191  35.324676  34.992858  37.957405  34.636193  46.790165
# 192  19.943532  19.658905  26.163973  27.163459  25.917014
#
# [193 rows x 8 columns]

# %%
import pandas as pd
import pycountry

# Function to convert country name to 3-letter ISO code
def get_country_code(name):
    try:
        return pycountry.countries.lookup(name).alpha_3
    except LookupError:
        return None  # or custom handling for unmatched names

# Apply the function to your 'Country Name' column
export2['Country Code'] = export2['Country Name'].apply(get_country_code)

# %%
export2
# Out:
#     Country Name                            Indicator Name       2015  \
# 0    Afghanistan  Exports of goods and services (% of GDP)        NaN
# 1        Albania  Exports of goods and services (% of GDP)  27.267391
# 2        Algeria  Exports of goods and services (% of GDP)  23.171778
# 3        Andorra  Exports of goods and services (% of GDP)        NaN
# 4         Angola  Exports of goods and services (% of GDP)  29.754598
# ..           ...                                       ...        ...
# 188    Venezuela  Exports of goods and services (% of GDP)        NaN
# 189      Vietnam  Exports of goods and services (% of GDP)  72.922848
# 190        Yemen  Exports of goods and services (% of GDP)  18.321800
# 191       Zambia  Exports of goods and services (% of GDP)  37.138526
# 192     Zimbabwe  Exports of goods and services (% of GDP)  19.160176
#
#           2016       2017       2018       2019       2020 Country Code
# 0          NaN        NaN        NaN        NaN        NaN          AFG
# 1    28.977899  31.569798  31.571954  31.304270  22.657790          ALB
# 2    20.872485  22.632232  25.861151  22.714404  17.469840          DZA
# 3          NaN        NaN        NaN        NaN        NaN          AND
# 4    28.124485  29.004102  40.836290  40.790755  38.038274          AGO
# ..         ...        ...        ...        ...        ...          ...
# 188        NaN        NaN        NaN        NaN        NaN          VEN
# 189  74.107286  81.762516  84.423458  85.157590  84.381595          VNM
# 190   5.977269   8.709109   6.056570        NaN        NaN          YEM
# 191  35.324676  34.992858  37.957405  34.636193  46.790165          ZMB
# 192  19.943532  19.658905  26.163973  27.163459  25.917014          ZWE
#
# [193 rows x 9 columns]

# %%
# Melt the dataframe
export_long = pd.melt(
    export2,
    id_vars=['Country Name', 'Indicator Name', 'Country Code'],
    value_vars=['2015', '2016', '2017', '2018', '2019', '2020'],
    var_name='Year',
    value_name='Export_Share_GDP'
)

# Convert 'Year' to integer
export_long['Year'] = export_long['Year'].astype(int)

# %%
export_long = export_long.rename(columns={'Country Code':"Origin"})

# %%
export_long
# Out:
#      Country Name                            Indicator Name Origin  Year  \
# 0     Afghanistan  Exports of goods and services (% of GDP)    AFG  2015
# 1         Albania  Exports of goods and services (% of GDP)    ALB  2015
# 2         Algeria  Exports of goods and services (% of GDP)    DZA  2015
# 3         Andorra  Exports of goods and services (% of GDP)    AND  2015
# 4          Angola  Exports of goods and services (% of GDP)    AGO  2015
# ...           ...                                       ...    ...   ...
# 1153    Venezuela  Exports of goods and services (% of GDP)    VEN  2020
# 1154      Vietnam  Exports of goods and services (% of GDP)    VNM  2020
# 1155        Yemen  Exports of goods and services (% of GDP)    YEM  2020
# 1156       Zambia  Exports of goods and services (% of GDP)    ZMB  2020
# 1157     Zimbabwe  Exports of goods and services (% of GDP)    ZWE  2020
#
#       Export_Share_GDP
# 0                  NaN
# 1            27.267391
# 2            23.171778
# 3                  NaN
# 4            29.754598
# ...                ...
# 1153               NaN
# 1154         84.381595
# 1155               NaN
# 1156         46.790165
# 1157         25.917014
#
# [1158 rows x 5 columns]

# %%
export_long = export_long.rename(columns={'Origin':'Country Code'})

# %%
new_panel = panel_merged.merge(export_long,on=['Country Code','Year'],how='left')
new_panel
# Out:
#             Origin  Year  Patent_Applications  \
# 0        Argentina  2015                856.0
# 1          Austria  2015              11261.0
# 2          Belgium  2015               8979.0
# 3         Bulgaria  2015                467.0
# 4           Canada  2015              23258.0
# ..             ...   ...                  ...
# 235         Turkey  2020               9353.0
# 236        Ukraine  2020               1654.0
# 237  United States  2020             470131.0
# 238        Uruguay  2020                 94.0
# 239     Uzbekistan  2020                379.0
#
#      Researchers in R&D (per million people)  GDP per Capita (USD)  \
# 0                                 1231.48660          13679.626498
# 1                                 5074.43000          43915.228021
# 2                                 4741.86040          40893.804538
# 3                                 1939.14420           7078.860323
# 4                                 4582.37940          43594.194105
# ..                                       ...                   ...
# 235                               1786.51710           8638.739038
# 236                                846.24850           3709.769287
# 237                               4451.78120          64411.373178
# 238                                813.23790          15789.685742
# 239                                426.82077           1978.280519
#
#      Research and development expenditure (% of GDP)  \
# 0                                            0.62262
# 1                                            3.04969
# 2                                            2.42817
# 3                                            0.94947
# 4                                            1.69359
# ..                                               ...
# 235                                          1.36748
# 236                                          0.40318
# 237                                          3.42467
# 238                                          0.67468
# 239                                          0.13850
#
#      Unemployemnt total (% of total labor force)  Country Code  gdp_growth  \
# 0                                           7.579          ARG     2.73116
# 1                                           5.802          AUT     1.01450
# 2                                           8.482          BEL     2.04146
# 3                                           9.143          BGR     3.39755
# 4                                           6.945          CAN     0.64997
# ..                                            ...          ...         ...
# 235                                        13.148          TUR     1.85984
# 236                                         9.475          UKR    -3.75280
# 237                                         8.055          USA    -2.21347
# 238                                        10.413          URY    -7.38010
# 239                                         5.293          UZB     1.99559
#
#      pop_growth       net_flow   edu_exp  stem_graduates   Country Name  \
# 0       1.07800            NaN       NaN             NaN      Argentina
# 1       1.12099   50254.347656  5.848230       29.271710        Austria
# 2       0.57945   42932.000000  7.123384       17.382830        Belgium
# 3      -0.63807  -12491.000000       NaN       20.793081       Bulgaria
# 4       0.76030  121634.000000  5.815642       20.027500         Canada
# ..          ...            ...       ...             ...            ...
# 235     0.97039  133756.000000       NaN       15.212980            NaN
# 236    -0.60161   -8580.000000       NaN       24.254510        Ukraine
# 237     0.96900  848728.187500  7.402097       19.553050  United States
# 238     0.01974   -2530.000000       NaN       15.237220        Uruguay
# 239     1.92213            NaN       NaN       36.932010     Uzbekistan
#
#                                Indicator Name  Export_Share_GDP
# 0    Exports of goods and services (% of GDP)         10.705652
# 1    Exports of goods and services (% of GDP)         53.089061
# 2    Exports of goods and services (% of GDP)         77.805282
# 3    Exports of goods and services (% of GDP)         63.800087
# 4    Exports of goods and services (% of GDP)         31.849961
# ..                                        ...               ...
# 235                                       NaN               NaN
# 236  Exports of goods and services (% of GDP)         38.821646
# 237  Exports of goods and services (% of GDP)         10.202126
# 238  Exports of goods and services (% of GDP)         25.208631
# 239  Exports of goods and services (% of GDP)         24.178316
#
# [240 rows x 16 columns]

# %%
new_panel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 16 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Origin                                           240 non-null    object
#  1   Year                                             240 non-null    int64
#  2   Patent_Applications                              240 non-null    float64
#  3   Researchers in R&D (per million people)          240 non-null    float64
#  4   GDP per Capita (USD)                             240 non-null    float64
#  5   Research and development expenditure (% of GDP)  240 non-null    float64
#  6   Unemployemnt total (% of total labor force)      240 non-null    float64
#  7   Country Code                                     240 non-null    object
#  8   gdp_growth                                       240 non-null    float64
#  9   pop_growth                                       240 non-null    float64
#  10  net_flow                                         221 non-null    float64
#  11  edu_exp                                          109 non-null    float64
#  12  stem_graduates                                   192 non-null    float64
#  13  Country Name                                     228 non-null    object
#  14  Indicator Name                                   228 non-null    object
#  15  Export_Share_GDP                                 225 non-null    float64
# dtypes: float64(11), int64(1), object(4)
# memory usage: 30.1+ KB

# %%
export_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1158 entries, 0 to 1157
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country Name      1158 non-null   object
#  1   Indicator Name    1158 non-null   object
#  2   Origin            1014 non-null   object
#  3   Year              1158 non-null   int64
#  4   Export_Share_GDP  1034 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 45.4+ KB

# %%
panel_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 13 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Origin                                           240 non-null    object
#  1   Year                                             240 non-null    int64
#  2   Patent_Applications                              240 non-null    float64
#  3   Researchers in R&D (per million people)          240 non-null    float64
#  4   GDP per Capita (USD)                             240 non-null    float64
#  5   Research and development expenditure (% of GDP)  240 non-null    float64
#  6   Unemployemnt total (% of total labor force)      240 non-null    float64
#  7   Country Code                                     240 non-null    object
#  8   gdp_growth                                       240 non-null    float64
#  9   pop_growth                                       240 non-null    float64
#  10  net_flow                                         221 non-null    float64
#  11  edu_exp                                          109 non-null    float64
#  12  stem_graduates                                   192 non-null    float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 24.5+ KB

# %%
new_panel = panel_merged.merge(
    export_long[['Origin', 'Year', 'Export_Share_GDP']],
    on=['Origin', 'Year'],
    how='left'
)

# %%
new_panel
# Out:
#             Origin  Year  Patent_Applications  \
# 0        Argentina  2015                856.0
# 1          Austria  2015              11261.0
# 2          Belgium  2015               8979.0
# 3         Bulgaria  2015                467.0
# 4           Canada  2015              23258.0
# ..             ...   ...                  ...
# 235         Turkey  2020               9353.0
# 236        Ukraine  2020               1654.0
# 237  United States  2020             470131.0
# 238        Uruguay  2020                 94.0
# 239     Uzbekistan  2020                379.0
#
#      Researchers in R&D (per million people)  GDP per Capita (USD)  \
# 0                                 1231.48660          13679.626498
# 1                                 5074.43000          43915.228021
# 2                                 4741.86040          40893.804538
# 3                                 1939.14420           7078.860323
# 4                                 4582.37940          43594.194105
# ..                                       ...                   ...
# 235                               1786.51710           8638.739038
# 236                                846.24850           3709.769287
# 237                               4451.78120          64411.373178
# 238                                813.23790          15789.685742
# 239                                426.82077           1978.280519
#
#      Research and development expenditure (% of GDP)  \
# 0                                            0.62262
# 1                                            3.04969
# 2                                            2.42817
# 3                                            0.94947
# 4                                            1.69359
# ..                                               ...
# 235                                          1.36748
# 236                                          0.40318
# 237                                          3.42467
# 238                                          0.67468
# 239                                          0.13850
#
#      Unemployemnt total (% of total labor force)  Country Code  gdp_growth  \
# 0                                           7.579          ARG     2.73116
# 1                                           5.802          AUT     1.01450
# 2                                           8.482          BEL     2.04146
# 3                                           9.143          BGR     3.39755
# 4                                           6.945          CAN     0.64997
# ..                                            ...          ...         ...
# 235                                        13.148          TUR     1.85984
# 236                                         9.475          UKR    -3.75280
# 237                                         8.055          USA    -2.21347
# 238                                        10.413          URY    -7.38010
# 239                                         5.293          UZB     1.99559
#
#      pop_growth       net_flow   edu_exp  stem_graduates  Export_Share_GDP
# 0       1.07800            NaN       NaN             NaN               NaN
# 1       1.12099   50254.347656  5.848230       29.271710               NaN
# 2       0.57945   42932.000000  7.123384       17.382830               NaN
# 3      -0.63807  -12491.000000       NaN       20.793081               NaN
# 4       0.76030  121634.000000  5.815642       20.027500               NaN
# ..          ...            ...       ...             ...               ...
# 235     0.97039  133756.000000       NaN       15.212980               NaN
# 236    -0.60161   -8580.000000       NaN       24.254510               NaN
# 237     0.96900  848728.187500  7.402097       19.553050               NaN
# 238     0.01974   -2530.000000       NaN       15.237220               NaN
# 239     1.92213            NaN       NaN       36.932010               NaN
#
# [240 rows x 14 columns]

# %%
new_panel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 14 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Origin                                           240 non-null    object
#  1   Year                                             240 non-null    int64
#  2   Patent_Applications                              240 non-null    float64
#  3   Researchers in R&D (per million people)          240 non-null    float64
#  4   GDP per Capita (USD)                             240 non-null    float64
#  5   Research and development expenditure (% of GDP)  240 non-null    float64
#  6   Unemployemnt total (% of total labor force)      240 non-null    float64
#  7   Country Code                                     240 non-null    object
#  8   gdp_growth                                       240 non-null    float64
#  9   pop_growth                                       240 non-null    float64
#  10  net_flow                                         221 non-null    float64
#  11  edu_exp                                          109 non-null    float64
#  12  stem_graduates                                   192 non-null    float64
#  13  Export_Share_GDP                                 0 non-null      float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 26.4+ KB

# %%
print(len(new_panel['Origin'].unique()))
# Out:
# 40
